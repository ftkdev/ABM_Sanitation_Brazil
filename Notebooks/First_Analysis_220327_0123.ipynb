# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/Results-1.35-0.1-2.5-0.25-35-1.4-0.1-0-2000.csv')

# %%
filt = (
    df['agente'] == 'nobid'
)
print(df.loc[filt, :].pivot_table(index='run', values='pop_alvo',
                                              aggfunc=np.sum))
# Out:
#       pop_alvo
# run
# 0     0.782283
# 1     0.721969
# 2     0.707591
# 3     0.802955
# 4     0.532448
# ...        ...
# 1995  0.827610
# 1996  0.530951
# 1997  0.910974
# 1998  0.576656
# 1999  0.761839
#
# [2000 rows x 1 columns]

# %%
chart = df.loc[filt, :].pivot_table(index='run', values='pop_alvo', aggfunc=np.sum)
chart.hist(figsize=(10,7))
# Out:
# array([[<AxesSubplot:title={'center':'pop_alvo'}>]], dtype=object)

# %%
plt.figure(figsize=(10,7))
chart.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart, x='pop_alvo')
# Out:
# <AxesSubplot:xlabel='pop_alvo', ylabel='Count'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=chart, y='pop_alvo')
# Out:
# <AxesSubplot:ylabel='pop_alvo'>
