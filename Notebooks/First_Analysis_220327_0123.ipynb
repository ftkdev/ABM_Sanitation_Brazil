# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
db_file1 = 'Results-0.8-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file2 = 'Results-0.9-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file3 = 'Results-1-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file4 = 'Results-1.1-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file5 = 'Results-1.2-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file6 = 'Results-1.3-0.1-2.5-0.25-25-1.4-0.1-0-2000'
db_file7 = 'Results-1.4-0.1-2.5-0.25-25-1.4-0.1-0.2-2000'
# db_file8 = 'Results-1.3-0.1-2.5-0.25-25-1.4-0.1-0-2000'

# %%
df1 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file1))
df2 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file2))
df3 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file3))
df4 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file4))
df5 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file5))
df6 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file6))
df7 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file7))
# df8 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results/{}.csv'.format(db_file8))

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df.columns
# Out:
# Index(['agente', 'agente_atratividade_min', 'agente_atratividade_max',
#        'agente_alpha_max', 'factor', 'agente_alpha_ofertado', 'bid',
#        'bid_number', 'estado', 'pop_alvo', 'outorga', 'projeto_outorga',
#        'investimento', 'retorno_curto_prazo', 'bid_alpha',
#        'projeto_atratividade_std', 'projeto_atratividade_min',
#        'projeto_atratividade_max', 'run', 'reruns', 'par_bid_alpha',
#        'par_std_alpha', 'par_atrat_avg', 'par_std_dev', 'par_number_of_agents',
#        'par_max_alpha', 'par_atrat_range', 'par_reatividade', 'par_runs',
#        'file_name'],
#       dtype='object')

# %%
filt = (
    df['agente'] == 'nobid'
)
print(df.loc[filt, :].pivot_table(index='run', values='pop_alvo',
                                              aggfunc=np.sum))
# Out:
#       pop_alvo
# run
# 0     2.602733
# 1     2.291390
# 2     2.621241
# 3     2.457858
# 4     2.414939
# ...        ...
# 1995  2.373270
# 1996  2.394554
# 1997  2.043436
# 1998  3.101050
# 1999  2.510989
#
# [2000 rows x 1 columns]

# %%
chart = df.loc[filt, :].pivot_table(index='run', values='pop_alvo', columns='file_name', aggfunc=np.sum)
chart.hist(figsize=(15,7), bins=50, sharex=True)
# Out:
# array([[<AxesSubplot:title={'center':'0.8-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'0.9-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>],
#        [<AxesSubplot:title={'center':'1.1-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1.2-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1.3-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>],
#        [<AxesSubplot:title={'center':'1.4-0.1-2.5-0.25-25-1.4-0.1-0.2-2000'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #ho 2235 interval plot for 365D (Draw)
# fig, axes = plt.subplots(nrows=2, ncols=3, sharex = True, sharey = True,  figsize = [20, 12])
# ax0, ax1, ax2, ax3, ax4, ax5 = axes.flatten()
#
# ax0.hist(df1['B365D'], bins=100)
# ax1.hist(df2['B365D'], bins=100)
# ax2.hist(df3['B365D'], bins=100)
# ax3.hist(df4['B365D'], bins=100)
# ax4.hist(df5['B365D'], bins=100)
# ax5.hist(df6['B365D'], bins=100)
# ax0.set_title('ho 2.2 - 2.4', fontsize=15)
# ax1.set_title('ho 2.4 - 2.6', fontsize=15)
# ax2.set_title('ho 2.6 - 2.8', fontsize=15)
# ax3.set_title('ho 2.8 - 3.0', fontsize=15)
# ax4.set_title('ho 3.0 - 3.2', fontsize=15)
# ax5.set_title('ho 3.2 - 3.5', fontsize=15)
#
# ax0.set_xlim([2,4])

# %%
plt.figure(figsize=(15,7))
chart.boxplot()
# Out:
# <AxesSubplot:>

# %%
chart_outorga = df.pivot_table(index='run', values='bid', columns='file_name', aggfunc=np.sum)
plt.figure(figsize=(10,7))
chart_outorga.hist(figsize=(15,7), bins=50, sharex=True)
# Out:
# array([[<AxesSubplot:title={'center':'0.8-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'0.9-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>],
#        [<AxesSubplot:title={'center':'1.1-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1.2-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>,
#         <AxesSubplot:title={'center':'1.3-0.1-2.5-0.25-25-1.4-0.1-0-2000'}>],
#        [<AxesSubplot:title={'center':'1.4-0.1-2.5-0.25-25-1.4-0.1-0.2-2000'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(15,7))
chart_outorga.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>SEABORN</b>

# %%
chart2 = df.loc[filt, :].pivot_table(index=['file_name','run'], values='pop_alvo', aggfunc=np.sum)

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart, x='1-0.1-2.5-0.25-25-1.4-0.1-0-2000', bins=15)
# Out:
# <AxesSubplot:xlabel='1-0.1-2.5-0.25-25-1.4-0.1-0-2000', ylabel='Count'>

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart2, x='pop_alvo', hue='file_name', multiple='dodge', bins = 10)
# Out:
# <AxesSubplot:xlabel='pop_alvo', ylabel='Count'>

# %%
chart3 = chart2.reset_index(level='file_name')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=chart3, y='pop_alvo', x='file_name')
# Out:
# <AxesSubplot:xlabel='file_name', ylabel='pop_alvo'>

# %%
df.columns
# Out:
# Index(['agente', 'agente_atratividade_min', 'agente_atratividade_max',
#        'agente_alpha_max', 'factor', 'agente_alpha_ofertado', 'bid',
#        'bid_number', 'estado', 'pop_alvo', 'outorga', 'projeto_outorga',
#        'investimento', 'retorno_curto_prazo', 'bid_alpha',
#        'projeto_atratividade_std', 'projeto_atratividade_min',
#        'projeto_atratividade_max', 'run', 'reruns', 'par_bid_alpha',
#        'par_std_alpha', 'par_atrat_avg', 'par_std_dev', 'par_number_of_agents',
#        'par_max_alpha', 'par_atrat_range', 'par_reatividade', 'par_runs',
#        'file_name'],
#       dtype='object')

# %%
chart_outorga = df.pivot_table(index='run', values='bid', aggfunc=np.sum)

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart_outorga, x='bid')
# Out:
# <AxesSubplot:xlabel='bid', ylabel='Count'>
