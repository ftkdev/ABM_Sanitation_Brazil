# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
db_file1 = 'Results-PJ-1-0.05-AG-0.5-0.25-25-1.4-0.3-g-GV-0-1-IT-2000'
db_file2 = 'Results-PJ-1-0.05-AG-0.5-0.25-30-1.4-0.3-g-GV-0-1-IT-2000'
db_file3 = 'Results-PJ-1-0.05-AG-0.5-0.25-35-1.4-0.3-g-GV-0-1-IT-2000'
db_file4 = 'Results-PJ-1-0.05-AG-0.5-0.25-40-1.4-0.3-g-GV-0-1-IT-2000'
db_file5 = 'Results-PJ-1-0.05-AG-0.5-0.25-45-1.4-0.3-g-GV-0-1-IT-2000'
db_file6 = 'Results-PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000'
# db_file7 = 'Results-PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000'
# db_file8 = 'Results-PJ-1-0.05-AG-0.5-0.25-100-1.4-0.3-g-GV-0-1-IT-2000'

# %%
df1 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file1))
df2 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file2))
df3 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file3))
df4 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file4))
df5 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file5))
df6 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file6))
# df7 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file7))
# df8 = pd.read_csv('/win/Users/faust/Documents/TCC_MBA/ABM_Project/Results_temp/{}.csv'.format(db_file8))

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6,])
# df = df1

# %%
df.columns
# Out:
# Index(['agente', 'ag_tamanho', 'ag_investimento', 'ag_max_alpha',
#        'ag_atratividade', 'factor', 'agente_alpha_ofertado', 'bid',
#        'bid_number', 'estado', 'pop_alvo', 'pop_alvo_ratio', 'pj_tamanho',
#        'pj_investimento', 'bid_alpha', 'outorga', 'run', 'reruns',
#        'par_bid_alpha', 'par_std_alpha', 'par_atrat_avg', 'par_std_dev',
#        'par_number_of_agents', 'par_max_alpha', 'par_atrat_lim',
#        'par_distribution', 'par_reatividade', 'par_reruns', 'par_runs',
#        'file_name'],
#       dtype='object')

# %%
filt = (
    df['agente'] == 'nobid'
)
print(df.loc[filt, :].pivot_table(index='run', values='pop_alvo_ratio',
                                              aggfunc=np.sum))

print(df.loc[filt, :].pivot_table(index='run', values='pop_alvo_ratio',
                                              aggfunc=np.sum).mean())
# Out:
#       pop_alvo_ratio
# run
# 0             0.8420
# 1             1.0202
# 2             1.1532
# 3             0.6519
# 4             0.5154
# ...              ...
# 1995          0.9255
# 1996          0.6124
# 1997          0.3682
# 1998          0.7304
# 1999          0.4930
#
# [2000 rows x 1 columns]
# pop_alvo_ratio    0.787196
# dtype: float64

# %%
chart = df.loc[filt, :].pivot_table(index='run', values='pop_alvo_ratio', columns='file_name', aggfunc=np.sum)
chart.hist(figsize=(15,7), bins=50, sharex=True, sharey=True)
# Out:
# array([[<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-25-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-30-1.4-0.3-g-GV-0-1-IT-2000'}>],
#        [<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-35-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-40-1.4-0.3-g-GV-0-1-IT-2000'}>],
#        [<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-45-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000'}>]],
#       dtype=object)

# %% [markdown]
# #ho 2235 interval plot for 365D (Draw)
# fig, axes = plt.subplots(nrows=2, ncols=3, sharex = True, sharey = True,  figsize = [20, 12])
# ax0, ax1, ax2, ax3, ax4, ax5 = axes.flatten()
#
# ax0.hist(df1['B365D'], bins=100)
# ax1.hist(df2['B365D'], bins=100)
# ax2.hist(df3['B365D'], bins=100)
# ax3.hist(df4['B365D'], bins=100)
# ax4.hist(df5['B365D'], bins=100)
# ax5.hist(df6['B365D'], bins=100)
# ax0.set_title('ho 2.2 - 2.4', fontsize=15)
# ax1.set_title('ho 2.4 - 2.6', fontsize=15)
# ax2.set_title('ho 2.6 - 2.8', fontsize=15)
# ax3.set_title('ho 2.8 - 3.0', fontsize=15)
# ax4.set_title('ho 3.0 - 3.2', fontsize=15)
# ax5.set_title('ho 3.2 - 3.5', fontsize=15)
#
# ax0.set_xlim([2,4])

# %%
plt.figure(figsize=(15,7))
chart.boxplot()
plt.xticks(rotation=10)
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, 'PJ-1-0.05-AG-0.5-0.25-25-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(2, 0, 'PJ-1-0.05-AG-0.5-0.25-30-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(3, 0, 'PJ-1-0.05-AG-0.5-0.25-35-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(4, 0, 'PJ-1-0.05-AG-0.5-0.25-40-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(5, 0, 'PJ-1-0.05-AG-0.5-0.25-45-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(6, 0, 'PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000')])

# %%
chart_outorga = df.pivot_table(index='run', values='bid', columns='file_name', aggfunc=np.sum)
plt.figure(figsize=(10,7))
chart_outorga.hist(figsize=(15,7), bins=50, sharex=True)
# Out:
# array([[<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-25-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-30-1.4-0.3-g-GV-0-1-IT-2000'}>],
#        [<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-35-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-40-1.4-0.3-g-GV-0-1-IT-2000'}>],
#        [<AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-45-1.4-0.3-g-GV-0-1-IT-2000'}>,
#         <AxesSubplot:title={'center':'PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000'}>]],
#       dtype=object)

# %%
plt.figure(figsize=(15,7))
chart_outorga.boxplot()
plt.xticks(rotation=10)
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, 'PJ-1-0.05-AG-0.5-0.25-25-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(2, 0, 'PJ-1-0.05-AG-0.5-0.25-30-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(3, 0, 'PJ-1-0.05-AG-0.5-0.25-35-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(4, 0, 'PJ-1-0.05-AG-0.5-0.25-40-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(5, 0, 'PJ-1-0.05-AG-0.5-0.25-45-1.4-0.3-g-GV-0-1-IT-2000'),
#   Text(6, 0, 'PJ-1-0.05-AG-0.5-0.25-50-1.4-0.3-g-GV-0-1-IT-2000')])

# %% [markdown]
# <b>SEABORN</b>

# %%
chart2 = df.loc[filt, :].pivot_table(index=['file_name','run'], values='pop_alvo', aggfunc=np.sum)

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart, x='1-0.1-2.5-0.25-25-1.4-0.1-0-2000', bins=15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_62104/3210269366.py in <module>
#       1 plt.figure(figsize=(10,7))
# ----> 2 sns.histplot(data=chart, x='1-0.1-2.5-0.25-25-1.4-0.1-0-2000', bins=15)
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1428 ):
#    1429
# -> 1430     p = _DistributionPlotter(
#    1431         data=data,
#    1432         variables=_DistributionPlotter.get_semantics(locals())
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     109     ):
#     110
# ...

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart2, x='pop_alvo', hue='file_name', multiple='dodge', bins = 10)

# %%
chart3 = chart2.reset_index(level='file_name')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=chart3, y='pop_alvo', x='file_name')

# %%
df.columns

# %%
chart_outorga = df.pivot_table(index='run', values='bid', aggfunc=np.sum)

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=chart_outorga, x='bid')
